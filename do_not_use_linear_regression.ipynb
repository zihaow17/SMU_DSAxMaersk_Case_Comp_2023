# %% [markdown]
# # Linear Regression

# %% [markdown]
# Use 'satisfaction score' instead of 'satisfaction' as target variable.

# %% [markdown]
# ## Libraries and read files

# %%
import pandas as pd
from sklearn.model_selection import KFold
import statsmodels.api as sm

# %%
df = pd.read_csv("Airline Passenger Satisfaction.csv").set_index('id').drop(columns=['Unnamed: 0'])
df.head()
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# id
# 70172     Male     Loyal Customer   13  Personal Travel  Eco Plus
# 5047      Male  disloyal Customer   25  Business travel  Business
# 110028  Female     Loyal Customer   26  Business travel  Business
# 24026   Female     Loyal Customer   25  Business travel  Business
# 119299    Male     Loyal Customer   61  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# id
# 70172               460                      3
# 5047                235                      3
# 110028             1142                      2
# 24026               562                      2
# 119299              214                      3
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# id
# 70172                                   4                       3
# 5047                                    2                       3
# 110028                                  2                       2
# 24026                                   5                       5
# 119299                                  3                       3
#
#         Gate location  ...  On-board service  Leg room service  \
# id                     ...
# 70172               1  ...                 4                 3
# 5047                3  ...                 1                 5
# 110028              2  ...                 4                 3
# 24026               5  ...                 2                 5
# 119299              3  ...                 3                 4
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# id
# 70172                  4                4                 5            5
# 5047                   3                1                 4            1
# 110028                 4                4                 4            5
# 24026                  3                1                 4            2
# 119299                 4                3                 3            3
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# id
# 70172                           25                        18
# 5047                             1                         6
# 110028                           0                         0
# 24026                           11                         9
# 119299                           0                         0
#
#                    satisfaction  satisfaction score
# id
# 70172   neutral or dissatisfied                   7
# 5047    neutral or dissatisfied                   3
# 110028                satisfied                   9
# 24026   neutral or dissatisfied                   6
# 119299                satisfied                  10
#
# [5 rows x 24 columns]

# %% [markdown]
# ## K-fold linear regression

# %%
# One-hot encode categorical data 
df = pd.get_dummies(df, columns=['Gender', 'Customer Type', 'Type of Travel', 'Class'])

# Isolate target variable from independent variables
X = df.drop(['satisfaction', 'satisfaction score'], axis=1)
y = df['satisfaction score']

# Set up KFold
k = 10
kf = KFold(n_splits=k, shuffle=True, random_state=1)

# Track best model
best_mse = float('inf')
best_model = None

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Create a linear regression model using statsmodels
    X_train_with_const = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train_with_const)
    results = model.fit()
    
    # Get the mean squared error (MSE) for this fold
    y_pred = results.predict(sm.add_constant(X_test))
    mse = ((y_test - y_pred) ** 2).mean()
    
    # Check if this model is better than the previous best model
    if mse < best_mse:
        best_mse = mse
        best_model = results

# Display the results of the best fit model
print("Best Fit Model Coefficients:\n")
for feature, coefficient, p_value in zip(X.columns, best_model.params[1:], best_model.pvalues[1:]):
    print(feature, ":", coefficient, "(p-value:", p_value, ")")
print("\nIntercept:", best_model.params[0])
# Out:
# Best Fit Model Coefficients:
#
# Age : -0.004766522028753011 (p-value: 8.75170297486186e-57 )
# Flight Distance : -1.9059158329072792e-05 (p-value: 0.00011217739036813655 )
# Inflight wifi service : 0.2140910466964094 (p-value: 0.0 )
# Departure/Arrival time convenient : 0.025800482375027186 (p-value: 4.0798219038929553e-13 )
# Ease of Online booking : -0.06135181573342661 (p-value: 1.3510638698058603e-35 )
# Gate location : 0.04225932984303359 (p-value: 1.3579052164319763e-25 )
# Food and drink : 0.09158152600345516 (p-value: 1.0338245215731735e-85 )
# Online boarding : 0.3751214580263409 (p-value: 0.0 )
# Seat comfort : 0.10988084704823428 (p-value: 2.5977316624998327e-109 )
# Inflight entertainment : 0.16742235594553548 (p-value: 8.925349367629145e-159 )
# On-board service : 0.2018166620485985 (p-value: 0.0 )
# Leg room service : 0.18532850039759785 (p-value: 0.0 )
# Baggage handling : 0.12910034760453215 (p-value: 1.2342940247993385e-150 )
# Checkin service : 0.2214435032343046 (p-value: 0.0 )
# Inflight service : 0.12612065473514616 (p-value: 1.5471425163846074e-131 )
# Cleanliness : 0.18809170475359252 (p-value: 3.613118843327745e-262 )
# Departure Delay in Minutes : 0.0012903047617248329 (p-value: 0.0010842830330574614 )
# Arrival Delay in Minutes : -0.0031465644273113895 (p-value: 9.20573539651572e-16 )
# Gender_Female : 0.025920917679323977 (p-value: 4.941942680895542e-05 )
# Gender_Male : 0.07090634458503116 (p-value: 2.666787007646327e-27 )
# Customer Type_Loyal Customer : 0.48466842675376076 (p-value: 0.0 )
# Customer Type_disloyal Customer : -0.3878411644894065 (p-value: 0.0 )
# Type of Travel_Business travel : 0.5681741788689121 (p-value: 0.0 )
# Type of Travel_Personal Travel : -0.4713469166045593 (p-value: 0.0 )
# Class_Business : 0.2790700085408341 (p-value: 1.4611820050135796e-168 )
# Class_Eco : -0.07727040853407054 (p-value: 7.094732111187939e-25 )
# Class_Eco Plus : -0.10497233774240992 (p-value: 2.638859019829345e-19 )
#
# Intercept: 0.09682726226435452

# %%
results_df = pd.DataFrame({'Feature': X.columns,
                           'Coefficient': best_model.params[1:],
                           'P-Value': best_model.pvalues[1:]})

results_df
# Out:
#                                                              Feature  \
# Age                                                              Age
# Flight Distance                                      Flight Distance
# Inflight wifi service                          Inflight wifi service
# Departure/Arrival time convenient  Departure/Arrival time convenient
# Ease of Online booking                        Ease of Online booking
# Gate location                                          Gate location
# Food and drink                                        Food and drink
# Online boarding                                      Online boarding
# Seat comfort                                            Seat comfort
# Inflight entertainment                        Inflight entertainment
# On-board service                                    On-board service
# Leg room service                                    Leg room service
# Baggage handling                                    Baggage handling
# Checkin service                                      Checkin service
# Inflight service                                    Inflight service
# Cleanliness                                              Cleanliness
# Departure Delay in Minutes                Departure Delay in Minutes
# Arrival Delay in Minutes                    Arrival Delay in Minutes
# Gender_Female                                          Gender_Female
# Gender_Male                                              Gender_Male
# Customer Type_Loyal Customer            Customer Type_Loyal Customer
# Customer Type_disloyal Customer      Customer Type_disloyal Customer
# Type of Travel_Business travel        Type of Travel_Business travel
# Type of Travel_Personal Travel        Type of Travel_Personal Travel
# Class_Business                                        Class_Business
# Class_Eco                                                  Class_Eco
# Class_Eco Plus                                        Class_Eco Plus
#
#                                    Coefficient        P-Value
# Age                                  -0.004767   8.751703e-57
# Flight Distance                      -0.000019   1.121774e-04
# Inflight wifi service                 0.214091   0.000000e+00
# Departure/Arrival time convenient     0.025800   4.079822e-13
# Ease of Online booking               -0.061352   1.351064e-35
# Gate location                         0.042259   1.357905e-25
# Food and drink                        0.091582   1.033825e-85
# Online boarding                       0.375121   0.000000e+00
# Seat comfort                          0.109881  2.597732e-109
# Inflight entertainment                0.167422  8.925349e-159
# On-board service                      0.201817   0.000000e+00
# Leg room service                      0.185329   0.000000e+00
# Baggage handling                      0.129100  1.234294e-150
# Checkin service                       0.221444   0.000000e+00
# Inflight service                      0.126121  1.547143e-131
# Cleanliness                           0.188092  3.613119e-262
# Departure Delay in Minutes            0.001290   1.084283e-03
# Arrival Delay in Minutes             -0.003147   9.205735e-16
# Gender_Female                         0.025921   4.941943e-05
# Gender_Male                           0.070906   2.666787e-27
# Customer Type_Loyal Customer          0.484668   0.000000e+00
# Customer Type_disloyal Customer      -0.387841   0.000000e+00
# Type of Travel_Business travel        0.568174   0.000000e+00
# Type of Travel_Personal Travel       -0.471347   0.000000e+00
# Class_Business                        0.279070  1.461182e-168
# Class_Eco                            -0.077270   7.094732e-25
# Class_Eco Plus                       -0.104972   2.638859e-19

# %%
sig_feat = []
crit_val = 0.001

for ind in results_df.index:
    if results_df['P-Value'][ind] < 0.05:
        sig_feat.append(results_df['Feature'][ind])

sig_feat
# Out:
# ['Age',
#  'Flight Distance',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'Gender_Female',
#  'Gender_Male',
#  'Customer Type_Loyal Customer',
#  'Customer Type_disloyal Customer',
#  'Type of Travel_Business travel',
#  'Type of Travel_Personal Travel',
#  'Class_Business',
#  'Class_Eco',
#  'Class_Eco Plus']
